# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cvlib
import cv2

# %%
model = tf.keras.models.load_model("model.h5")
class_name =['WithMask', 'WithoutMask']

# %%
test1 = cv2.imread("images/test1.jpg")
test1 = cv2.cvtColor(test1, cv2.COLOR_BGR2RGB)
test1 = cv2.resize(test1,(224,224))
plt.imshow(test1)
plt.title("Test 1 img")
plt.xticks([])
plt.yticks([])
plt.show()
test1 = np.expand_dims(test1, 0)
print(f"Test 1 {class_name[np.argmax(model.predict(test1))]}")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# Test 1 WithMask

# %%
test2 = cv2.imread("images/test2.jpg")
test2 = cv2.cvtColor(test2, cv2.COLOR_BGR2RGB)
test2 = cv2.resize(test2,(224,224))
plt.imshow(test2)
plt.title("test2")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
face2 = cvlib.detect_face(test2)
face2 = face2[0][0]
face_2 = test2[face2[0]:face2[2], face2[1]:face2[3]]
face_2 = cv2.resize(face_2, (224,224))
plt.imshow(face_2)
plt.xticks([])
plt.yticks([])
face_2 = np.expand_dims(face_2, 0)
plt.title(class_name[np.argmax(model.predict(face_2))])
plt.show()
# Out:
# 1/1 [==============================] - 0s 18ms/step

# %%
test3 = cv2.imread("images/test3.jpeg")
test3 = cv2.cvtColor(test3, cv2.COLOR_BGR2RGB)
test3 = cv2.resize(test3,(224,224))
plt.imshow(test3)
plt.title("test3")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
face3 = cvlib.detect_face(test3)
face3 = face3[0][0]
face_3 = test3[face3[0]:face3[2], face3[1]:face3[3]]
face_3 = cv2.resize(face_3, (224,224))
plt.imshow(face_3)
plt.xticks([])
plt.yticks([])
face_3 = np.expand_dims(face_3,0)
plt.title(class_name[np.argmax(model.predict(face_3))])
plt.show()
# Out:
# 1/1 [==============================] - 0s 17ms/step

# %%
test4 = cv2.imread("images/test4.jpg")
test4 = cv2.cvtColor(test4, cv2.COLOR_BGR2RGB)
test4 = cv2.resize(test4,(224,224))
plt.imshow(test4)
plt.title("test4")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
face4 = cvlib.detect_face(test4)
face4 = face4[0][0]
face_4 = test4[face4[0]:face4[2], face4[1]:face4[3]]
face_4 = cv2.resize(face_4, (224, 224))
plt.imshow(face_4)
face_4 = np.expand_dims(face_4,0)
plt.title(class_name[np.argmax(model.predict(face_4))])
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# 1/1 [==============================] - 0s 17ms/step
